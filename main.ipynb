# %%
FILE_NAME = "surgery_indicator.csv"
FILE_PATH = "./RawData/" + FILE_NAME

# %%
import pandas as pd

df = pd.read_csv(FILE_PATH)

# %%
df.head(100)
# Out:
#                       ข้อมูลตัวชี้วัด กลุ่มด้านมะเร็ง  Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN         NaN        NaN
# 1                                   ข้อมูล/ตัวชี้วัด     เป้าหมาย    ปี 2561
# 2                                                 NaN  ปีปัจจุบัน        NaN
# 3                                1.ผู้ป่วยกลุ่มมะเร็ง         NaN        NaN
# 4                 เรื่อง PPS ใช้เกณฑ์ palliative care         NaN        NaN
# ..                                                ...         ...        ...
# 95                                                NaN         NaN   (0/1799)
# 96                      ศูนย์เคมีบำบัดว่องวานิชชั้น 8         NaN          0
# 97                                                NaN         NaN      0/185
# 98               เรื่อง Hypersensitivity ในยาแต่ละ...         NaN        NaN
# 99  อัตราการเกิดภาวะHypersensitivity จากยา Taxol g...         <2%       4.48
#
# ...

# %%
# whats with this data?

df_cleaned = df.dropna()

df = df_cleaned

df.head(100)
# Out:
# Empty DataFrame
# Columns: [ข้อมูลตัวชี้วัด กลุ่มด้านมะเร็ง, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8]
# Index: []
